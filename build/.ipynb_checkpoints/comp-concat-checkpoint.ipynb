# %%
import pandas as pd 
import glob

# %%
csv_files = glob.glob("/Users/eren/Desktop/SFND/Camera/SFND_2D_Feature_Tracking/build/*.csv")
print(csv_files[0])
print(len(csv_files))
# Out:
# /Users/eren/Desktop/SFND/Camera/SFND_2D_Feature_Tracking/build/comp-SIFT-BRIEF-MAT_FLANN-SEL_KNN-.csv
# 110

# %%
df_all = pd.read_csv(csv_files[0], skiprows=2, names=['Detector Type', 'Detector Time', '#KP', 'Descriptor Type', 'Descriptor Time', 'Matcher Type', 'Selector Type', 'Matching Time', '#Matched KP']) 

for i in range(1, len(csv_files)):
    df = pd.read_csv(csv_files[i], skiprows=2, names=['Detector Type', 'Detector Time', '#KP', 'Descriptor Type', 'Descriptor Time', 'Matcher Type', 'Selector Type', 'Matching Time', '#Matched KP']) 
    df_all = pd.concat([df_all, df])

df_all.head()
# Out:
#   Detector Type  Detector Time  #KP Descriptor Type  Descriptor Time  \
# 0          FAST        4.24096  150             ORB          25.5426
# 1          FAST        7.29364  155             ORB          15.0424
# 2          FAST        5.65444  149             ORB          11.2496
# 3          FAST        2.74693  149             ORB          10.4012
# 4          FAST        2.71367  156             ORB          13.0739
#
#   Matcher Type Selector Type  Matching Time  #Matched KP
# 0       MAT_BF       SEL_KNN       2.005380          122
# 1       MAT_BF       SEL_KNN       1.182790          115
# 2       MAT_BF       SEL_KNN       1.243040          129
# 3       MAT_BF       SEL_KNN       0.888915          107
# 4       MAT_BF       SEL_KNN       1.009880          120

# %%
df_all.head()
# Out:
#   Detector Type  Detector Time  #KP Descriptor Type  Descriptor Time  \
# 0          SIFT        158.046  121           BRIEF          1.81724
# 1          SIFT        134.239  135           BRIEF          2.07513
# 2          SIFT        135.069  134           BRIEF          2.12223
# 3          SIFT        138.638  139           BRIEF          1.87113
# 4          SIFT        147.370  136           BRIEF          1.81965
#
#   Matcher Type Selector Type  Matching Time #Matched KP
# 0    MAT_FLANN       SEL_KNN        1.84757          70
# 1    MAT_FLANN       SEL_KNN        1.55479          60
# 2    MAT_FLANN       SEL_KNN        1.69470          65
# 3    MAT_FLANN       SEL_KNN        1.65941          52
# 4    MAT_FLANN       SEL_KNN        1.72016          60

# %%
df_all.to_csv('comp_all.csv')
